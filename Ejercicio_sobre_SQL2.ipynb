# %% [markdown]
# <a href="https://colab.research.google.com/github/wilsonfffs/CODING-DOJO/blob/main/Ejercicio_sobre_SQL2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import pandas as pd
from sqlalchemy import create_engine
# montar datos
from google.colab import drive
drive.mount('/content/drive')
# cargar datos: ¡cambia la ruta para que coincida con tu unidad!
school = pd.read_csv('/content/drive/MyDrive/Coding Dojo /Codigo /week12/School_Details.csv')
# Asegúrate de que estén cargados correctamente
school.head(2)
# Out:
# Mounted at /content/drive
#   DistrictName EstablishmentCode  \
# 0         East             S0169
# 1         East             S0099
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
#
#   ManagementName LocalityHabitation SubdivisionName ConstituencyName  ...  \
# 0    State Govt.             BUDANG         Gangtok          Rhenock  ...
# 1    State Govt.     CENTRAL PENDAM         Gangtok      West Pandam  ...
#
#   EstablishedDate DistrictHQDistance (in Km) CRCDistance (in Km)  \
# 0           28126                       58.0                 8.0
# 1           15342                       50.0                 0.0
#
# ...

# %%
facility = pd.read_csv('/content/drive/MyDrive/Coding Dojo /Codigo /week12/School_Facility_Details.csv')
facility.head(2)
# Out:
#   EstablishmentCode                                  EstablishmentName  \
# 0             S1034  (I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PR...
# 1             S0516                10TH MILE GOVERNMENT PRIMARY SCHOOL
#
#   IsLibraryAvailable  AvailableBooksCount IsFireExtgAvailable  \
# 0      Not Available                    0           Available
# 1      Not Available                    0       Not Available
#
#    ExtinguisherCount HOIRoomAvailable IsStaffRoomAvailable  NoofStaffRoom  \
# 0                  1        Available        Not Available              0
# 1                  0        Available            Available              1
#
#   IsLockerForStaffAvailable IsSportsStoreRoomAvailable
# 0             Not Available              Not Available
# 1             Not Available              Not Available

# %%
# imports
import pandas as pd
from sqlalchemy import create_engine

# %%
# crear motor sqlite
engine = create_engine('sqlite:///school.db', echo=True)
# crear conexión con el motor
conn = engine.connect()

# %%
# agregarel marco de datos como una tabla en sqlite
sqlite_table = "school_details"
school.to_sql(sqlite_table, conn, if_exists='fail')
sqlite_table2 = "school_facility_details"
facility.to_sql(sqlite_table2, conn, if_exists='fail')
# Out:
# 2022-04-03 00:09:33,825 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("school_details")
# 2022-04-03 00:09:33,827 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-03 00:09:33,831 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("school_details")
# 2022-04-03 00:09:33,833 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-04-03 00:09:33,846 INFO sqlalchemy.engine.Engine
# CREATE TABLE school_details (
# 	"index" BIGINT,
# 	"DistrictName" TEXT,
# 	"EstablishmentCode" TEXT,
# 	"EstablishmentName" TEXT,
# 	"BRCName" TEXT,
# 	"CRCName" TEXT,
# 	"SchoolLevel" TEXT,
# 	"ManagementName" TEXT,
# 	"LocalityHabitation" TEXT,
# 	"SubdivisionName" TEXT,
# 	"ConstituencyName" TEXT,
# 	"RevenueBlockName" TEXT,
# 	"CivicBodyName" TEXT,
# 	"WardName" TEXT,
# 	"PostOfficeName" TEXT,
# 	"PhoneNo" TEXT,
# 	"FaxNo" TEXT,
# 	"EmailID" TEXT,
# 	"Website" TEXT,
# 	"LocatedInRuralOrUrban" TEXT,
# 	"DiseCode" TEXT,
# 	"EstablishedDate" TEXT,
# 	"DistrictHQDistance (in Km)" FLOAT,
# ...

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT AVG([BACDistance (in Km)]) as avg_bac_distance
FROM school_details
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-03 00:10:32,617 INFO sqlalchemy.engine.Engine SELECT AVG([BACDistance (in Km)]) as avg_bac_distance
# FROM school_details
#
# 2022-04-03 00:10:32,624 INFO sqlalchemy.engine.Engine [raw sql] ()
#    avg_bac_distance
# 0         12.681822

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT SchoolLevel, AVG([BACDistance (in Km)]) as avg_bac_distance
FROM school_details
GROUP BY SchoolLevel
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-03 00:10:55,519 INFO sqlalchemy.engine.Engine SELECT SchoolLevel, AVG([BACDistance (in Km)]) as avg_bac_distance
# FROM school_details
# GROUP BY SchoolLevel
#
# 2022-04-03 00:10:55,521 INFO sqlalchemy.engine.Engine [raw sql] ()
#   SchoolLevel  avg_bac_distance
# 0        None               NaN
# 1         JHS         13.692647
# 2         LPS          5.368421
# 3          PS         12.830787
# 4          SS         12.630872

# %%
sql = """
select avg("BACDistance (in Km)") as "avg_bac_distancia"
from school_details
group by SchoolLevel
having "avg_bac_distancia" < 10
order by "avg_bac_distancia" desc

"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-03 00:12:22,485 INFO sqlalchemy.engine.Engine
# select avg("BACDistance (in Km)") as "avg_bac_distancia"
# from school_details
# group by SchoolLevel
# having "avg_bac_distancia" < 10
# order by "avg_bac_distancia" desc
#
#
# 2022-04-03 00:12:22,489 INFO sqlalchemy.engine.Engine [raw sql] ()
#    avg_bac_distancia
# 0           5.368421

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT SchoolLevel, AVG([BACDistance (in Km)]) as avg_bac_distance
FROM school_details
GROUP BY SchoolLevel
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-03 00:14:38,555 INFO sqlalchemy.engine.Engine SELECT SchoolLevel, AVG([BACDistance (in Km)]) as avg_bac_distance
# FROM school_details
# GROUP BY SchoolLevel
#
# 2022-04-03 00:14:38,558 INFO sqlalchemy.engine.Engine [raw sql] ()
#   SchoolLevel  avg_bac_distance
# 0        None               NaN
# 1         JHS         13.692647
# 2         LPS          5.368421
# 3          PS         12.830787
# 4          SS         12.630872

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT SchoolLevel, AVG([BACDistance (in Km)]) as avg_bac_distance
FROM school_details
GROUP BY SchoolLevel
HAVING AVG([BACDistance (in Km)]) < 10
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-03 00:14:55,617 INFO sqlalchemy.engine.Engine SELECT SchoolLevel, AVG([BACDistance (in Km)]) as avg_bac_distance
# FROM school_details
# GROUP BY SchoolLevel
# HAVING AVG([BACDistance (in Km)]) < 10
#
# 2022-04-03 00:14:55,619 INFO sqlalchemy.engine.Engine [raw sql] ()
#   SchoolLevel  avg_bac_distance
# 0         LPS          5.368421

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT *
FROM school_details sd, school_facility_details sfd
WHERE sd.EstablishmentCode = sfd.EstablishmentCode
LIMIT 2
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-03 00:15:11,638 INFO sqlalchemy.engine.Engine SELECT *
# FROM school_details sd, school_facility_details sfd
# WHERE sd.EstablishmentCode = sfd.EstablishmentCode
# LIMIT 2
#
# 2022-04-03 00:15:11,641 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index DistrictName EstablishmentCode  \
# 0      0         East             S0169
# 1      1         East             S0099
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
#
#   ManagementName LocalityHabitation SubdivisionName  ...  \
# 0    State Govt.             BUDANG         Gangtok  ...
# 1    State Govt.     CENTRAL PENDAM         Gangtok  ...
#
# ...

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT *
FROM school_details sd, school_facility_details sfd
WHERE sd.EstablishmentCode = sfd.EstablishmentCode AND
SchoolLevel = 'PS' AND
IsLibraryAvailable <> 'Available'
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-03 00:15:25,373 INFO sqlalchemy.engine.Engine SELECT *
# FROM school_details sd, school_facility_details sfd
# WHERE sd.EstablishmentCode = sfd.EstablishmentCode AND
# SchoolLevel = 'PS' AND
# IsLibraryAvailable <> 'Available'
#
# 2022-04-03 00:15:25,376 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index DistrictName EstablishmentCode  \
# 0      5         East             S0856
# 1      8         East             S0876
# 2     15         East             S1230
# 3     16         East             S0768
# 4     20         East             S0131
#
#                         EstablishmentName   BRCName  \
# 0        EASWARAMMA SAI GURUKOOL ACCADEMY  Duga Brc
# 1     NEW GARDEN BOARDING SCHOOL (SAJONG)  Duga Brc
# 2     SARASWATI SHISHU VIDHYALAYA, BUDANG  Duga Brc
# 3        SAWNEY GOVERNMENT PRIMARY SCHOOL  Duga Brc
# 4  UPPER PACHAK GOVERNMENT PRIMARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# ...

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT *
FROM school_details sd, school_facility_details sfd
WHERE sd.EstablishmentCode = sfd.EstablishmentCode AND
SchoolLevel = 'PS' AND
IsLibraryAvailable <> 'Available'
ORDER BY EstablishmentName
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-03 00:15:52,284 INFO sqlalchemy.engine.Engine SELECT *
# FROM school_details sd, school_facility_details sfd
# WHERE sd.EstablishmentCode = sfd.EstablishmentCode AND
# SchoolLevel = 'PS' AND
# IsLibraryAvailable <> 'Available'
# ORDER BY EstablishmentName
#
# 2022-04-03 00:15:52,286 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index DistrictName EstablishmentCode  \
# 0   1219         West             S1034
# 1     54         East             S0516
# 2    816        South             S0692
# 3   1102         West             S0374
# 4    209         East             S0108
#
#                                    EstablishmentName      BRCName  \
# 0  (I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PR...   Yuksom Brc
# 1                10TH MILE GOVERNMENT PRIMARY SCHOOL  Gangtok Brc
# 2                  AAPGAZI GOVERNMENT PRIMARY SCHOOL     Temi Brc
# 3                AARUBOTEY GOVERNMENT PRIMARY SCHOOL   Soreng Brc
# ...
