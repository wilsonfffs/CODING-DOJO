# %% [markdown]
# <a href="https://colab.research.google.com/github/wilsonfffs/CODING-DOJO/blob/main/Ejercicio_sobre_conceptos_b%C3%A1sicos_de_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import pandas as pd
from sqlalchemy import create_engine

# %%
# montar datos
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# cargar datos: ¡cambia la ruta para que coincida con tu unidad!
school = pd.read_csv('/content/drive/MyDrive/Coding Dojo /Codigo /week12/School_Details.csv')
# Asegúrate de que estén cargados correctamente
school.head(2)
# Out:
#   DistrictName EstablishmentCode  \
# 0         East             S0169
# 1         East             S0099
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
#
#   ManagementName LocalityHabitation SubdivisionName ConstituencyName  ...  \
# 0    State Govt.             BUDANG         Gangtok          Rhenock  ...
# 1    State Govt.     CENTRAL PENDAM         Gangtok      West Pandam  ...
#
#   EstablishedDate DistrictHQDistance (in Km) CRCDistance (in Km)  \
# 0           28126                       58.0                 8.0
# 1           15342                       50.0                 0.0
#
#   BACDistance (in Km) IsRecognized RecognizedBy ContactPersonName LowestClass  \
# 0                16.0   Recognized         HRDD               NaN     Class 1
# 1                 6.0   Recognized         HRDD               NaN     Class 1
#
#   HighestClass BoardName
# 0      Class 5       NaN
# 1     Class 12  C.B.S.E.
#
# [2 rows x 30 columns]

# %%
engine = create_engine('sqlite:///school.db', echo=True)
# crear conexión con el motor
conn = engine.connect()

# agregar marco de datos como una tabla en sqlite
sqlite_table = "school_details"
school.to_sql(sqlite_table, conn, if_exists='fail')
# Out:
# 2022-04-02 23:43:28,114 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("school_details")
# 2022-04-02 23:43:28,115 INFO sqlalchemy.engine.Engine [raw sql] ()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-5d773c565c3d> in <module>()
#       5 # agregar marco de datos como una tabla en sqlite
#       6 sqlite_table = "school_details"
# ----> 7 school.to_sql(sqlite_table, conn, if_exists='fail')
#       8
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1756             index_label=index_label,
#    1757             schema=schema,
# -> 1758             dtype=dtype,
#    1759         )
#    1760
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1648             dtype=dtype,
#    1649         )
# -> 1650         table.create()
#    1651         return table
#    1652
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/sql.py in create(self)
#     856         if self.exists():
#     857             if self.if_exists == "fail":
# --> 858                 raise ValueError(f"Table '{self.name}' already exists.")
#     859             elif self.if_exists == "replace":
#     860                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'school_details' already exists.

# %%
sql = """SELECT * 
FROM school_details
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.columns.values
# Out:
# 2022-04-02 23:44:42,290 INFO sqlalchemy.engine.Engine SELECT *
# FROM school_details
#
# 2022-04-02 23:44:42,292 INFO sqlalchemy.engine.Engine [raw sql] ()
# array(['index', 'DistrictName', 'EstablishmentCode', 'EstablishmentName',
#        'BRCName', 'CRCName', 'SchoolLevel', 'ManagementName',
#        'LocalityHabitation', 'SubdivisionName', 'ConstituencyName',
#        'RevenueBlockName', 'CivicBodyName', 'WardName', 'PostOfficeName',
#        'PhoneNo', 'FaxNo', 'EmailID', 'Website', 'LocatedInRuralOrUrban',
#        'DiseCode', 'EstablishedDate', 'DistrictHQDistance (in Km)',
#        'CRCDistance (in Km)', 'BACDistance (in Km)', 'IsRecognized',
#        'RecognizedBy', 'ContactPersonName', 'LowestClass', 'HighestClass',
#        'BoardName'], dtype=object)

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT EstablishmentName, SchoolLevel, Website
FROM school_details
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-02 23:45:10,864 INFO sqlalchemy.engine.Engine SELECT EstablishmentName, SchoolLevel, Website
# FROM school_details
#
# 2022-04-02 23:45:10,865 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                    EstablishmentName SchoolLevel  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)          PS
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL         SSS
# 2              CENTRAL POINT ACADEMY, CENTRAL PENDAM          SS
# 3      CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)         JHS
# 4                   DUGA GOVERNMENT SECONDARY SCHOOL          SS
#
#                                      Website
# 0                                       None
# 1                                       None
# 2  www.facebook.com/khanalkeshav (Group-CPA)
# 3                                       None
# 4                                       None

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT EstablishmentName, [DistrictHQDistance (in Km)]
FROM school_details
WHERE [DistrictHQDistance (in Km)] > 100
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-02 23:45:32,946 INFO sqlalchemy.engine.Engine SELECT EstablishmentName, [DistrictHQDistance (in Km)]
# FROM school_details
# WHERE [DistrictHQDistance (in Km)] > 100
#
# 2022-04-02 23:45:32,950 INFO sqlalchemy.engine.Engine [raw sql] ()
#                     EstablishmentName  DistrictHQDistance (in Km)
# 0  DODACHEN GOVERNMENT PRIMARY SCHOOL                       150.0
# 1   DEOLING GOVERNMENT PRIMARY SCHOOL                       107.0
# 2       PEMA TSEL ACADEMY(PHADAMCHEN)                       110.0
# 3    ZULUCK GOVERNMENT PRIMARY SCHOOL                       120.0
# 4   BHARENG GOVERNMENT PRIMARY SCHOOL                       150.0

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT EstablishmentName, SchoolLevel, [DistrictHQDistance (in Km)]
FROM school_details
WHERE SchoolLevel == 'JHS'
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-02 23:45:53,778 INFO sqlalchemy.engine.Engine SELECT EstablishmentName, SchoolLevel, [DistrictHQDistance (in Km)]
# FROM school_details
# WHERE SchoolLevel == 'JHS'
#
# 2022-04-02 23:45:53,779 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                EstablishmentName SchoolLevel  \
# 0  CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)         JHS
# 1               PADMA KUMARI PUBLIC SCHOOL, DUGA         JHS
# 2           SAJONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 3      SINGLEYBONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 4                          SUNRISE ACADEMY, DUGA         JHS
#
#    DistrictHQDistance (in Km)
# 0                        60.0
# 1                        48.0
# 2                        57.0
# 3                        38.0
# 4                        47.0

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT EstablishmentName, SchoolLevel, [DistrictHQDistance (in Km)]
FROM school_details
WHERE EstablishmentName like '%Junior High%'
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-02 23:46:15,953 INFO sqlalchemy.engine.Engine SELECT EstablishmentName, SchoolLevel, [DistrictHQDistance (in Km)]
# FROM school_details
# WHERE EstablishmentName like '%Junior High%'
#
# 2022-04-02 23:46:15,956 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                EstablishmentName SchoolLevel  \
# 0  CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)         JHS
# 1           SAJONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 2      SINGLEYBONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 3          BORDANG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 4     RANGPO BAZAR GOVERNMENT JUNIOR HIGH SCHOOL         JHS
#
#    DistrictHQDistance (in Km)
# 0                        60.0
# 1                        57.0
# 2                        38.0
# 3                        33.0
# 4                        47.0

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT EstablishmentName
FROM school_details
WHERE LocatedInRuralOrUrban = 'Urban Area'
ORDER BY EstablishmentName DESC
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-02 23:46:31,966 INFO sqlalchemy.engine.Engine SELECT EstablishmentName
# FROM school_details
# WHERE LocatedInRuralOrUrban = 'Urban Area'
# ORDER BY EstablishmentName DESC
#
# 2022-04-02 23:46:31,969 INFO sqlalchemy.engine.Engine [raw sql] ()
#                        EstablishmentName
# 0       ZULUCK GOVERNMENT PRIMARY SCHOOL
# 1       ZOOM GOVERNMENT SECONDARY SCHOOL
# 2  ZITLANG GOVERNMENT JUNIOR HIGH SCHOOL
# 3       ZINGLA GOVERNMENT PRIMARY SCHOOL
# 4                   ZENITH PUBLIC SCHOOL

# %%
# Escribe tu consulta SQL en esta cadena
sql = """SELECT EstablishmentName as nombre
FROM school_details
WHERE LocatedInRuralOrUrban = 'Urban Area'
ORDER BY EstablishmentName DESC
"""
# Lee la consulta sql en pandas para ver los resultados
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
# 2022-04-02 23:46:57,432 INFO sqlalchemy.engine.Engine SELECT EstablishmentName as nombre
# FROM school_details
# WHERE LocatedInRuralOrUrban = 'Urban Area'
# ORDER BY EstablishmentName DESC
#
# 2022-04-02 23:46:57,438 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                   nombre
# 0       ZULUCK GOVERNMENT PRIMARY SCHOOL
# 1       ZOOM GOVERNMENT SECONDARY SCHOOL
# 2  ZITLANG GOVERNMENT JUNIOR HIGH SCHOOL
# 3       ZINGLA GOVERNMENT PRIMARY SCHOOL
# 4                   ZENITH PUBLIC SCHOOL
